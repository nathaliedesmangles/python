# %% [markdown]
# # 🔬 Projet : Enquête scientifique par analyse d’ADN
#
# Bienvenue dans cette mission d’analyse génétique médico-légale. Vous allez explorer les données ADN de plusieurs suspects afin d’identifier celui ou ceux qui pourraient correspondre à l’échantillon trouvé sur une scène de crime. Bonne chance… et que la science soit avec vous ! 😉

# %% [markdown]
# ## 🧭 1. Élaboration du plan de travail
#
# Décrivez ici les étapes que vous comptez suivre pour résoudre le problème. Précisez quelles fonctions vous allez créer, dans quel ordre vous comptez procéder, et comment vous allez structurer votre code.

# %% [markdown]
# ## 🧼 2. Chargement et nettoyage des données

# %%
# Importation des bibliothèques autorisées
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Chargement du fichier CSV
df = pd.read_csv("suspects.csv")

# Affichage des premières lignes
df.head()

# %% [markdown]
# ## 🧮 3. Calculs de correspondance
#
# Créez ici les fonctions permettant de comparer deux séquences ADN malgré les caractères `?` et calculez les taux de correspondance pour chaque suspect.

# %% [markdown]
# ## 📊 4. Résumé et visualisation des résultats
#
# Présentez vos résultats dans un tableau synthèse, puis créez un graphique à barres pour chaque suspect avec des barres d’erreur ±5 %.

# %% [markdown]
# ## 📈 5. Analyse statistique (régression linéaire)
#
# Choisissez deux loci, appliquez une régression linéaire, tracez la droite et affichez l’équation avec incertitude.

# %% [markdown]
# ## 🧠 6. Interprétation des résultats
#
# Dans cette section Markdown, interprétez vos résultats : suspect(s) probable(s), incertitudes, limites méthodologiques, suggestions d'amélioration.

# %% [markdown]
# ## 🧪 Bonus (facultatif) : Limites biologiques
#
# Ajoutez ici des éléments de réflexion sur les limites de l’analyse ADN dans un contexte réel.
