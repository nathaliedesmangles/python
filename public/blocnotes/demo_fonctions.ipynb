# %% [markdown]
# # Demo-Fonctions
#
# Complète les cellules manquantes selon les consignes.

# %% [markdown]
# ## 1 Introduction – Pourquoi créer une fonction ?

# %%
# 💡 Reproduis ici le code sans fonction et observe la répétition

# %% [markdown]
# ## 2 Définir une fonction simple

# %%
# 💡 Définis ici la fonction aire_rectangle(longueur, largeur)
# Elle doit afficher l'aire du rectangle

# %% [markdown]
# ## 3 Retourner un résultat avec `return`

# %%
# 💡 Modifie la fonction pour qu'elle retourne la valeur au lieu de l'afficher

# %% [markdown]
# ## 4 Arrêt d’exécution après `return`

# %%
# 💡 Observe ce qui se passe quand tu ajoutes du code après return

# %% [markdown]
# ## 5 Retourner plusieurs valeurs

# %%
# 💡 Définis une fonction calculer_statistiques(notes)
# qui retourne la moyenne, le minimum et le maximum

# %% [markdown]
# ## 6 Portée locale des variables

# %%
# 💡 Crée une fonction test() qui définit x à l'intérieur puis essaie de l'afficher à l'extérieur

# %% [markdown]
# ## 7 Docstrings et documentation

# %%
# 💡 Écris une fonction multiplication(a, b) avec une docstring complète

# %% [markdown]
# ## 8 Démonstration finale intégrée

# %%
# 💡 Écris ici les deux fonctions volume_boite() et afficher_volume()
# puis teste ton programme

# %% [markdown]
# ### À retenir
# - `def` définit une fonction
# - `return` renvoie un résultat
# - Les variables dans une fonction sont locales
# - Documente toujours ton code !
