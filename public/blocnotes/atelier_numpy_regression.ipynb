# %% [markdown]
# # 🌱 Exercice : Analyse d’une expérience sur l’effet de la lumière sur la croissance des plantes
#
# Une équipe de recherche a mesuré la hauteur (en cm) de jeunes plantes après 10 jours de croissance dans trois conditions lumineuses différentes :
#
# - lumière naturelle
# - lumière LED blanche
# - lumière LED rouge
#
# Pour chaque condition, 5 plantes ont été mesurées. Certaines données sont manquantes, car une ou deux plantes n’ont pas survécu. Les données brutes sont les suivantes :
#
# | Condition   | Plante 1 | Plante 2 | Plante 3 | Plante 4 | Plante 5 |
# | ----------- | -------- | -------- | -------- | -------- | -------- |
# | Naturelle   | 12.5     | 13.1     | 12.9     | 13.0     | 12.8     |
# | LED blanche | 11.2     | 11.6     | np.nan   | 11.5     | 11.3     |
# | LED rouge   | 10.4     | 10.1     | 10.2     | np.nan   | np.nan   |
#
# ### 🎯 Objectifs
# 1. Représenter les données dans un tableau NumPy 2D
# 2. Calculer la moyenne et l'écart-type pour chaque condition (en ignorant les `NaN`)
# 3. Comparer les hauteurs moyennes et afficher la meilleure condition
# 4. Afficher un résumé clair
# 5. Afficher un graphique avec barres d’erreur

# %%
# Étape 1 – Représente les données dans un tableau NumPy 2D
import numpy as np

# Données brutes (à compléter avec np.nan si nécessaire)
donnees = np.array([
    # ...
])

conditions = ["Naturelle", "LED blanche", "LED rouge"]

# %%
# Étape 2 – Calcul des moyennes et écarts-types (ignorer les NaN)
# ...

# %%
# Étape 3 – Identifier la condition avec la plus grande croissance moyenne
# ...

# %%
# Étape 4 – Afficher un résumé clair
# ...

# %%
# Étape 5 – Créer un graphique avec barres d’erreur
import matplotlib.pyplot as plt

# ...
