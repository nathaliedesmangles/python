# %% [markdown]
# # Atelier – Boucles et conditions en Python
#
# ## Exercice 1 – For ou While ?
#
# Pour chacun des contextes suivants, répondez à la question : "Quelle boucle devriez-vous utiliser (for ou while) ?" Ensuite, écrivez le code correspondant.
#
# **a.** Afficher les nombres de 1 à 10
# **b.** Compter jusqu’à 100 par bonds de 10
# **c.** Simuler la chute d’un objet de 100 m (baisse de 10 m/s)
# **d.** Lire une température jusqu’à ce qu’elle soit < 0 (entrée utilisateur)
# **e.** Demander un chiffre (1 à 10). Tant que ce n’est pas 0, redemander. Si c’est 0, arrêter le programme.

# %% [markdown]
# ## Exercice 2 – Table de multiplication
#
# Écrire un programme qui affiche la table de multiplication d’un nombre donné (entre 1 et 12). Répéter tant que l’utilisateur le souhaite.
#
# **Exemple de sortie :**
# ```
# Entrez un nombre entre 1 et 12 : 7
# 1 x 7 = 7
# ...
# 12 x 7 = 84
# ```

# %% [markdown]
# ## Exercice 3 – Température croissante
#
# Une température commence à 20 °C et augmente de 1.5 °C par heure.
#
# 1. Crée une variable `temp = 20`
# 2. Tant que la température est < 30, affiche sa valeur et ajoute 1.5

# %% [markdown]
# ## Exercice 4 – Afficher des échantillons
#
# Utilise une boucle `for` pour afficher :
# ```
# Échantillon 1
# Échantillon 2
# ...
# Échantillon 10
# ```

# %% [markdown]
# ## Exercice 5 – Corriger un code avec erreurs
#
# Corrige le code suivant :
# ```python
# nom = input("Quel est ton nom?")
# print("Bonjour", name)
#
# age = input("Quel âge as-tu?")
# print("Dans 10 ans, tu auras" age + 10)
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

# Données
hauteur = np.linspace(0, 50, 6)  # [0, 10, 20, 30, 40, 50]
pression = np.array([101.3, 100.0, 98.7, 97.5, 96.2, 95.0])

# 1. Affiche les hauteurs et les pressions
print("Hauteur (cm) :", hauteur)
print("Pression (kPa) :", pression)

# 2. Variation de pression par tranche de 10 cm
variation = np.diff(pression)  # différences successives
print("Variation de pression par 10 cm :", variation)

# 3. Moyenne de pression
moyenne_pression = np.mean(pression)
print("Moyenne de pression :", moyenne_pression, "kPa")

# 4. Régression linéaire pour Pression = a*Hauteur + b
a, b = np.polyfit(hauteur, pression, 1)

# Tracé
plt.scatter(hauteur, pression, label="Mesures", color="blue")
plt.plot(hauteur, a*hauteur + b, label=f"Régression linéaire: y={a:.2f}x+{b:.2f}", color="red")
plt.xlabel("Hauteur (cm)")
plt.ylabel("Pression (kPa)")
plt.title("Pression en fonction de la hauteur")
plt.legend()
plt.grid(True)
plt.savefig("graphique_pression_regression.png")
plt.show()
# Out:
# Hauteur (cm) : [ 0. 10. 20. 30. 40. 50.]
# Pression (kPa) : [101.3 100.   98.7  97.5  96.2  95. ]
# Variation de pression par 10 cm : [-1.3 -1.3 -1.2 -1.3 -1.2]
# Moyenne de pression : 98.11666666666667 kPa
