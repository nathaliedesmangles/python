# %% [markdown]
# # Démo NumPy - Bases
# Ce carnet présente les bases de NumPy, création de tableaux et fonctions mathématiques/statistiques de base.

# %%
import numpy as np

# %% [markdown]
# ## Création de tableaux

# %%
# 1. Avec np.array()
liste = [2, 4, 6]
t = np.array(liste)
print(t)  # [2 4 6]

# %%
# 2. Avec np.arange()
t = np.arange(0, 5, 1)
print(t)  # [0 1 2 3 4]

# %%
# 3. Avec np.linspace()
t = np.linspace(0, 10, 5)
print(t)  # [0.  2.5  5.  7.5 10.]

# %%
# 4. Avec np.ones()
t = np.ones(4)
print(t)  # [1. 1. 1. 1.]

# %%
# 5. Avec np.zeros()
t = np.zeros(3)
print(t)  # [0. 0. 0.]

# %% [markdown]
# ## Fonctions mathématiques

# %%
t = np.array([4, 9, 16])
print(np.sqrt(t))  # Racine carrée

# %%
t = np.array([27, 64, 216])
print(np.cbrt(t))  # Racine cubique

# %%
t = np.array([0, 1, 2])
print(np.exp(t))  # Exponentielle

# %%
t = np.array([1, np.e, np.e**2])
print(np.log(t))  # Logarithme naturel

# %%
t = np.array([1, 2, 4, 8])
print(np.log2(t))  # Log base 2

# %%
t = np.array([1, 10, 100, 0.1])
print(np.log10(t))  # Log base 10

# %% [markdown]
# ## Fonctions statistiques

# %%
t = np.array([3, 7, 2, 9])
print(np.sum(t))  # Somme

# %%
print(np.prod(t))  # Produit

# %%
print(np.max(t))  # Max
print(np.min(t))  # Min

# %%
t = np.array([80, 90, 100])
print(np.mean(t))  # Moyenne

# %%
t = np.array([1, 2, 3, 4])
print(np.median(t))  # Médiane

# %%
print(np.var(t))  # Variance
print(np.std(t))  # Écart-type
