# %% [markdown]
# # ❄️ Exercice – Température de cristallisation
#
# On a réalisé des expériences pour mesurer la température de cristallisation de différentes substances dans plusieurs conditions (pression normale, pression élevée, en solution aqueuse, etc.).

# %% [markdown]
# ## 💾 Données (dans un fichier `cristallisation.csv`)
# ```csv
# substance,condition,temp_cristallisation
# NaCl,pression_normale,801
# NaCl,en_solution,800
# H2O,pression_normale,0
# H2O,pression_elevee,-1
# Fe,pression_normale,1538
# Fe,en_solution,1530
# ```

# %% [markdown]
# ## Étape 1 – Lecture du fichier CSV
# 👉 Lis les données et construis un dictionnaire structuré comme ceci :
# ```python
# {
#     "NaCl": {"pression_normale": 801, "en_solution": 800},
#     "H2O": {"pression_normale": 0, "pression_elevee": -1},
#     "Fe": {"pression_normale": 1538, "en_solution": 1530}
# }
# ```

# %%
import csv

donnees = {}

# À compléter : lecture du fichier 'cristallisation.csv'
# Astuce : utiliser csv.reader avec open(...)
# Ignorer l’en-tête avec next()

print(donnees)

# %% [markdown]
# ## Étape 2 – Affichage lisible des données
# 👉 Pour chaque substance et chaque condition, affiche une phrase comme :
# `NaCl cristallise à 801°C sous pression normale.`

# %%
# À compléter : parcourir le dictionnaire et afficher les phrases

# %% [markdown]
# ## Étape 3 – Ajouter une nouvelle mesure
# 👉 Ajoute : `H2O` – `en_solution` – `-5°C`

# %%
# À compléter : ajout de la nouvelle condition à H2O

# %% [markdown]
# ## Étape 4 – Vérifier la présence de 'Cu'
# 👉 Affiche un message si 'Cu' n’est pas présent dans les données.

# %%
# À compléter

# %% [markdown]
# ## Étape 5 – Substances avec cristallisation < 100°C
# 👉 Affiche toutes les substances ayant au moins une température < 100°C

# %%
# À compléter

# %% [markdown]
# ## Étape 6 – Comparer les écarts de température
# 👉 Pour chaque substance, calcule et affiche l’écart maximal de température entre conditions

# %%
# À compléter
